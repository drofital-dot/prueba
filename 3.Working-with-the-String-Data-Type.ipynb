# %%
myString = "This is a string."
print(myString)
# Out:
# This is a string.

# %%
print(type(myString))
# Out:
# <class 'str'>

# %%
print(myString + " is of the data type " + str(type(myString)))
# Out:
# This is a string. is of the data type <class 'str'>

# %%
firstString = "water"
secondString = "fall"
thirdString = firstString + secondString
print(thirdString)
# Out:
# waterfall

# %%
name = "Cristian"

# %%
print(name)
# Out:
# Cristian

# %%
color = "verde"
animal = "gato"

# %%
print("{}, te gusta {} {}!".format(name,color,animal))
# Out:
# Cristian, te gusta verde gato!
