# %%
import subprocess

def clean_environment():
    print("Ejecutando autoremove...")
    subprocess.run(["sudo", "apt-get", "autoremove", "-y"], check=True)

    print("Ejecutando autoclean...")
    subprocess.run(["sudo", "apt-get", "autoclean"], check=True)

    print("Limpieza finalizada.")
