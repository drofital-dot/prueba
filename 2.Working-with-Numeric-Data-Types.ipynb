# %%
print("Python has three numeric types: int, float, and complex")
# Out:
# Python has three numeric types: int, float, and complex

# %%
myValue=1
print (myValue)
# Out:
# 1

# %%
print(type(myValue))
# Out:
# <class 'int'>

# %%
print(str(myValue) + " es del tipo de dato " + str(type(myValue)))
# Out:
# 1 es del tipo de dato <class 'int'>

# %%
myValuefloat=3.14

# %%
print(myValuefloat)
# Out:
# 3.14

# %%
print(type(myValuefloat))
# Out:
# <class 'float'>

# %%
print(str(myValuefloat) + " is of the data type " + str(type(myValuefloat)))
# Out:
# 3.14 is of the data type <class 'float'>

# %%
myValueComplex=5j

# %%
print(myValueComplex)
# Out:
# 5j

# %%
print(type(myValueComplex))
# Out:
# <class 'complex'>

# %%
print(str(myValueComplex) + " is of the data type " + str(type(myValueComplex)))
# Out:
# 5j is of the data type <class 'complex'>

# %%
myValueBool=True

# %%
print(myValueBool)
# Out:
# True

# %%
print(type(myValueBool))
# Out:
# <class 'bool'>

# %%
print(str(myValueBool) + " is of the data type " + str(type(myValueBool)))
# Out:
# True is of the data type <class 'bool'>

# %%
myValueBoolf=False

# %%
print(myValueBoolf)
# Out:
# False

# %%
print(type(myValueBoolf))
# Out:
# <class 'bool'>

# %%
print(str(myValueBoolf) + " is of the data type " + str(type(myValueBoolf)))
# Out:
# False is of the data type <class 'bool'>
